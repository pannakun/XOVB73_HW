# %% [markdown]
# 1. Task: GitHub

# %%
token = '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'

# %%
# !git config --global user.email panna.kun@gmail.com
# !git config --global user.name pannakun

# %%
username = "pannakun"
repo = "XOVB73_HW"

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'XOVB73_HW'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %pwd
# Out:
# '/content/XOVB73_HW'

# %%
# %cd /content/XOVB73_HW
# Out:
# /content/XOVB73_HW

# %%
# !touch createdfile.txt

# %%
# !echo "first line of the file" > createdfile.txt
# !echo "second line of the file" >> createdfile.txt

# %%
# !git add createdfile.txt

# %%
# !git commit -m "upload another file"
# Out:
# [main 2d77fd6] upload another file
#  1 file changed, 1 insertion(+)

# %%
# !git push
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 313 bytes | 313.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/pannakun/XOVB73_HW
#    d82f9c9..2d77fd6  main -> main
